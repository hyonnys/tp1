# %% [markdown]
# <a href="https://colab.research.google.com/github/hyonnys/tp1/blob/main/tp1_RegressionData_modelpipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Part 0. Data Loading**

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.13.5)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.1)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.1

# %%
import os
import pandas as pd
import numpy as np
from category_encoders import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score, RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost.sklearn import XGBRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct, ConstantKernel
from sklearn.metrics import r2_score as r2, mean_squared_error as mse, mean_absolute_error as mae
import datetime as dt
from tqdm import tqdm
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
abalone = pd.read_csv('/content/drive/MyDrive/regression_data.csv')
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# # **Part 1. Data Engineering**<br>
# - Outlier Drop :  `Height (> 0.4)`

# %%
# data engineering
# height outlier 확인
outlier_height = abalone[abalone['Height'] > 0.4]
outlier_height
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1417   M   0.705     0.565   0.515         2.210          1.1075
# 2051   F   0.455     0.355   1.130         0.594          0.3320
#
#       Viscera weight  Shell weight  Rings
# 1417          0.4865        0.5120     10
# 2051          0.1160        0.1335      8

# %%
# Height outlier 데이터 제거 및 결과 확인
abalone.drop(outlier_height.index, inplace=True)
abalone[abalone['Height']>0.4]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %% [markdown]
# # **Part 2. Data Preprocessing**<br>
# #### 💡 수치형 변수<br>
# Scale Standardization<br>
# - MinMaxScaler : 모든 값을 0과 1 사이의 값으로 조정 (이상치 민감)
# - StandardScaler : 특성의 평균을 0, 표준편차를 1로 조정 (이상치 덜 민감)
# <br>
#
# Normalization <br>
# - Log 변환 : 다수 값들이 제한된 범위 내에서만 존재하고 특정 값들이 큰 형태의 분포에서 사용됨 (모든 값이 음수가 아니여야 함)
# <br>
#
# #### 💡 범주형 변수<br>
# - One Hot Encoding
#   + 각 범주형 특성 값들을 각 값들에 대해 해당하는지/하지 않는지를 1과 0으로 인코딩한다. 차원을 늘릴 수 있다.
#   + 특성의 정보를 분산시키므로 트리 기반 모델에는 비효율적이다.
# - Ordinal Encoding
#   + 특성 값들을 서로 다른 정수 값들로 인코딩함
#   + 양적 대소 관계를 갖는 것처럼 간주되므로 선형 회귀 모델 보다 트리 기반 모델에서 효율적임.
# <br>

# %% [markdown]
# ## **2-1. First Experiment**<br>
#
# > ### *Data Preprocessing*<br>
# - 수치형 변수 : **_Standard Scaling_**
# - 범주형 변수 `Sex` : **_One Hot Encoding_**
#
# <br>
#
# > ### *Model Selection*<br>
# - Linear Regressison
# - Ridge
# - RandomForestRegressor
# - Gradient Boosting Regressor
# - KNeighbors Regressor
# - SVM - SVR
# <br>
#
# > ### *Results*<br>
# -
# <br>

# %% [markdown]
# **📌 [sklearn.feature_selection.SelectKBest](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html?highlight=selectkbest#sklearn.feature_selection.SelectKBest)**

# %%
abalone1 = abalone.copy()

# %%
# 데이터 분리 기능
def data_split(df, target, features):
  y = df[target]
  x= df[features]
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)
  print(f'x_train: {x_train.shape}, y_train: {y_train.shape}')
  print(f'x_test: {x_test.shape}, y_test: {y_test.shape}')
  return x_train, x_test, y_train, y_test

# %%
target = 'Rings'
features1 = abalone1.columns.difference(['Rings'])
x_train, x_test, y_train, y_test = data_split(abalone1, target, features1)
# Out:
# x_train: (3131, 8), y_train: (3131,)
# x_test: (1044, 8), y_test: (1044,)

# %%
numeric_feats = x_train.dtypes[x_train.dtypes != "object"].index
categoric_feats = x_train.dtypes[x_train.dtypes == "object"].index

# %%
sscaler = StandardScaler()
x_train[numeric_feats] = sscaler.fit_transform(x_train[numeric_feats])
# x_val[numeric_feats] = sscaler.transform(x_val[numeric_feats])
x_test[numeric_feats] = sscaler.transform(x_test[numeric_feats])

# %%
# scaling 결과 확인
# 평균 0에 가까운 수로, 표준편차 1에 가까운 수로 변환되었는지 확인
x_train[numeric_feats].describe().T[['mean', 'std']]
# Out:
#                         mean      std
# Diameter        1.089302e-16  1.00016
# Height         -3.631007e-17  1.00016
# Length         -1.815504e-16  1.00016
# Shell weight   -6.808139e-17  1.00016
# Shucked weight -1.860891e-16  1.00016
# Viscera weight  2.496318e-17  1.00016
# Whole weight   -3.177131e-17  1.00016

# %%
# OneHotEncoder : categorical feature - Sex
ohe = OneHotEncoder()
x_train_ohe = ohe.fit_transform(x_train)
x_test_ohe = ohe.transform(x_test)

# 결과 확인
print((x_train_ohe.dtypes == 'object').sum())
print((x_test_ohe.dtypes == 'object').sum())
# Out:
# 0
# 0

# %%
# data preprocessing 결과 확인
x_train_ohe.head()
# Out:
#       Diameter    Height    Length  Sex_1  Sex_2  Sex_3  Shell weight  \
# 2667  0.414915  0.272779  0.501373      1      0      0     -0.109638
# 4086  0.414915  0.403271  0.543362      0      1      0     -0.001912
# 2552 -1.869461 -1.684603 -1.808021      0      0      1     -1.463391
# 1804  0.617971  0.142287  0.795296      0      1      0      0.116586
# 247  -1.361822 -1.423619 -1.388131      0      0      1     -1.222803
#
#       Shucked weight  Viscera weight  Whole weight
# 2667        0.476648        0.195746      0.213957
# 4086        0.035414        0.291626      0.083463
# 2552       -1.333311       -1.320068     -1.382547
# 1804        0.674753        0.821248      0.516742
# 247        -1.290539       -1.278976     -1.295892

# %%
# OrdinalEncoding
le = OrdinalEncoder()
x_train_le = le.fit_transform(x_train)
x_test_le = le.transform(x_test)

# 결과 확인
print((x_train_le.dtypes == 'object').sum())
print((x_test_le.dtypes == 'object').sum())
# Out:
# 0
# 0

# %%
# 성능 결과 출력 기능
def print_score(model, X_train, y_train, X_test, y_test) :

    train_score = np.round(model.score(X_train, y_train) , 3)
    val_score = np.round(np.mean(cross_val_score(model, X_train, y_train, scoring='r2', cv=5).round(3)),3)
    test_score = np.round(model.score(X_test, y_test),3)
    d = {'train':train_score, 'val':val_score, 'test':test_score}
    ser = pd.Series(data=d, index=['train', 'val', 'test'])

    return train_score, val_score, test_score, ser

# %%
# LinearRegression
ols = LinearRegression()
ols.fit(x_train_le, y_train)

# 성능 비교
ols_train, ols_val, ols_test, ols_ser = print_score(ols,x_train_le, y_train, x_test_le, y_test)

# %%
# 성능 확인
ols_ser
# Out:
# train    0.530
# val      0.524
# test     0.565
# dtype: float64

# %%
# Ridge
rg = Ridge()
rg.fit(x_train_le, y_train)

# 성능 비교
rg_train, rg_val, rg_test, rg_ser = print_score(rg,x_train_le, y_train, x_test_le, y_test)

# %%
# RandomForestRegressor_le
rf = RandomForestRegressor()
rf.fit(x_train_le, y_train)

# 성능 비교
rf_train, rf_val, rf_test, rf_ser = print_score(rf,x_train_le, y_train, x_test_le, y_test)

# %%
# SVM
svr = SVR()
svr.fit(x_train_le, y_train)

#성능 비교
svr_train, svr_val, svr_test, svr_ser = print_score(svr,x_train_le, y_train, x_test_le, y_test)

# %%
# GradientBoostingRegressor
gb = GradientBoostingRegressor()
gb.fit(x_train_le, y_train)

# 성능 비교
gb_train, gb_val, gb_test, gb_ser = print_score(gb,x_train_le, y_train, x_test_le, y_test)

# %%
# KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors = 4)
knn.fit(x_train_le, y_train)

# 성능 비교
knn_train, knn_val, knn_test, knn_ser = print_score(knn,x_train_le, y_train, x_test_le, y_test)

# %%
frame = {'ols':ols_ser, 'ridge':rg_ser, 'rf':rf_ser, 'svr':svr_ser, 'gb':gb_ser, 'knn':knn_ser}
pd.DataFrame(frame)
# Out:
#          ols  ridge     rf    svr     gb    knn
# train  0.530  0.530  0.933  0.544  0.661  0.676
# val    0.524  0.525  0.530  0.529  0.537  0.438
# test   0.565  0.565  0.565  0.572  0.573  0.499

# %% [markdown]
# ## **2-2. Second Experiment**<br>
# > ### *Data Preprocessing*<br>
# - 수치형 변수 : **_MinMax_** Scaling
# - 범주형 변수 : **_Drop_**
# <br>
#
# > ### *Model Selection*<br>
# - RandomForestRegressor
# - Gradient Boosting Regressor
# - KNeighbors Regressor
# - SVM - SVR
# <br>
#
# > ### *Results*<br>
# -
# <br>

# %%
abalone2 = abalone.copy()

# %%
target = 'Rings'
features2 = abalone2.columns.difference(['Rings', 'Sex'])
x_train2, x_test2, y_train2, y_test2 = data_split(abalone2, target, features2)
# Out:
# x_train: (3131, 7), y_train: (3131,)
# x_test: (1044, 7), y_test: (1044,)

# %%
mscaler = MinMaxScaler()
x_train_mscaled = mscaler.fit_transform(x_train2)
x_test_mscaled = mscaler.transform(x_test2)

# %%
# LinearRegression
ols.fit(x_train_mscaled, y_train)
ols_train, ols_val, ols_test, ols_ser2 = print_score(ols,x_train_mscaled, y_train, x_test_mscaled, y_test)

# Ridge
rg.fit(x_train_mscaled, y_train)
rg_train, rg_val, rg_test, rg_ser2 = print_score(rg,x_train_mscaled, y_train, x_test_mscaled, y_test)


# RandomForestRegressor
rf.fit(x_train_mscaled, y_train)
rf_train, rf_val, rf_test, rf_ser2 = print_score(rf,x_train_mscaled, y_train, x_test_mscaled, y_test)

# SVR
svr.fit(x_train_mscaled, y_train)
svr_train, svr_val, svr_test, svr_ser2 = print_score(svr,x_train_mscaled, y_train, x_test_mscaled, y_test)

# GradientBoostingRegressor
gb.fit(x_train_mscaled, y_train)
gb_train, gb_val, gb_test, gb_ser2 = print_score(gb,x_train_mscaled, y_train, x_test_mscaled, y_test)

# KNeighborsRegressor
knn.fit(x_train_mscaled, y_train)
knn_train, knn_val, knn_test, knn_ser2 = print_score(knn,x_train_mscaled, y_train, x_test_mscaled, y_test)

# %%
# XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train_mscaled, y_train)

xgb_train, xgb_val, xgb_test, xgb_ser2 = print_score(xgb,x_train_mscaled, y_train, x_test_mscaled, y_test)

# %%
# 모델 성능 비교
frame2 = {'ols':ols_ser2, 'ridge':rg_ser2, 'rf':rf_ser2, 'svr':svr_ser2,'xgb':xgb_ser2, 'gb':gb_ser2, 'knn':knn_ser2}
pd.DataFrame(frame2)
# Out:
#          ols  ridge     rf    svr    xgb     gb    knn
# train  0.526  0.517  0.935  0.527  0.941  0.651  0.669
# val    0.521  0.510  0.526  0.514  0.480  0.527  0.437
# test   0.557  0.546  0.555  0.555  0.493  0.563  0.498

# %% [markdown]
# ## **2-3. Third Experiment**<br>
# > ### *Data Engineering*<br>
# - Outlier Drop :  `Height (> 0.4)`
# <br>
#
# > ### *Data Preprocessing*<br>
# - Numerical Features
#   + **_Log_** Scaling
# - **_Drop Categorical Feature `Sex`_**
# <br>
#
# > ### *Model Selection*<br>
# - Polynomial Regressor
# - RandomForestRegressor
# - Gradient Boosting Regressor
# - KNeighbors Regressor
# - SVM - SVR
# - Gaussian Process Regressor
# - XGBRegressor

# %%
x_train_log = np.log1p(x_train2)
x_test_log = np.log1p(x_test2)

# %%
def PolynomialRegression(degree=2, **kwargs):
    return make_pipeline(PolynomialFeatures(degree),
                         LinearRegression(**kwargs))

poly_ols = PolynomialRegression(degree=2)
poly_ols.fit(x_train_log, y_train)

poly_train, poly_val, poly_test, poly_ser3 = print_score(poly_ols,x_train_log, y_train, x_test_log, y_test)

# %%
# LinearRegression
ols.fit(x_train_log, y_train)
ols_train, ols_val, ols_test, ols_ser3 = print_score(ols,x_train_log, y_train, x_test_log, y_test)

# Ridge
rg.fit(x_train_log, y_train)
rg_train, rg_val, rg_test, rg_ser3 = print_score(rg,x_train_log, y_train, x_test_log, y_test)


# RandomForestRegressor
rf.fit(x_train_log, y_train)
rf_train, rf_val, rf_test, rf_ser3 = print_score(rf,x_train_log, y_train, x_test_log, y_test)

# SVR
svr.fit(x_train_log, y_train)
svr_train, svr_val, svr_test, svr_ser3 = print_score(svr,x_train_log, y_train, x_test_log, y_test)

# GradientBoostingRegressor
gb.fit(x_train_log, y_train)
gb_train, gb_val, gb_test, gb_ser3 = print_score(gb,x_train_log, y_train, x_test_log, y_test)

# KNeighborsRegressor
knn.fit(x_train_log, y_train)
knn_train, knn_val, knn_test, knn_ser3 = print_score(knn,x_train_log, y_train, x_test_log, y_test)

# %%
# Gaussian Process Regressor
gpr = GaussianProcessRegressor()
gpr.fit(x_train_log, y_train)

gpr_train, gpr_val, gpr_test, gpr_ser3 = print_score(gpr,x_train_log, y_train, x_test_log, y_test)

# %%
# XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train_log, y_train)

xgb_train, xgb_val, xgb_test, xgb_ser3 = print_score(xgb,x_train_log, y_train, x_test_log, y_test)

# %%
frame3 = {'ols':ols_ser3,'poly_ols':poly_ser3, 'ridge':rg_ser3, 'rf':rf_ser3, 'svr':svr_ser3,\
          'xgb':xgb_ser3, 'gb':gb_ser3, 'knn':knn_ser3, 'gpr':gpr_ser3}
pd.DataFrame(frame3)
# Out:
#          ols  poly_ols  ridge     rf    svr    xgb     gb    knn    gpr
# train  0.547     0.577  0.534  0.934  0.530  0.941  0.651  0.688  0.673
# val    0.542     0.560  0.526  0.519  0.520  0.480  0.529  0.474 -0.204
# test   0.576     0.598  0.566  0.558  0.568  0.493  0.564  0.542 -6.096

# %% [markdown]
# ## **2-4.Fourth Experiment**<br>
# ### Data Engineering<br>
# - Outlier Drop :  `Height (> 0.4)` , `Rings (> 15)`
# <br>
#
# ### Data Preprocessing<br>
# - 수치형 변수 : log 변환
# - 범주형 변수 : Ordinal Encoding
# <br>
#
# ### Results<br>
# -

# %%
abalone3 = abalone.copy()

# %%
outlier_rings = abalone3[abalone3['Rings']> 15]
outlier_rings
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 32     M   0.665     0.525   0.165        1.3380          0.5515
# 33     F   0.680     0.550   0.175        1.7980          0.8150
# ...   ..     ...       ...     ...           ...             ...
# 3929   F   0.650     0.515   0.215        1.4980          0.5640
# 3930   F   0.670     0.535   0.185        1.5970          0.6275
# 3931   I   0.550     0.440   0.165        0.8605          0.3120
# 3944   M   0.550     0.440   0.160        0.9910          0.3480
# 3947   M   0.475     0.365   0.140        0.6175          0.2020
#
#       Viscera weight  Shell weight  Rings
# 6             0.1415         0.330     20
# 7             0.1495         0.260     16
# 9             0.1510         0.320     19
# 32            0.3575         0.350     18
# 33            0.3925         0.455     19
# ...              ...           ...    ...
# 3929          0.3230         0.425     16
# 3930          0.3500         0.470     21
# 3931          0.1690         0.300     17
# 3944          0.1680         0.375     20
# 3947          0.1445         0.190     16
#
# [261 rows x 9 columns]

# %%
abalone3.drop(outlier_rings.index, inplace=True)
abalone3[abalone3['Rings']> 15]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
# 데이터 분리
target = 'Rings'
features3 = abalone3.columns.difference(['Rings'])
x_train3, x_test3, y_train3, y_test3 = data_split(abalone3, target, features3)
# Out:
# x_train: (2935, 8), y_train: (2935,)
# x_test: (979, 8), y_test: (979,)

# %%
# Log 변환
x_train3[numeric_feats] = np.log1p(x_train3[numeric_feats])
x_test3[numeric_feats] = np.log1p(x_test3[numeric_feats])

# %%
# OrdinalEncoding
le = OrdinalEncoder()
x_train3_le = le.fit_transform(x_train3)
x_test3_le = le.transform(x_test3)

# 결과 확인
print((x_train3_le.dtypes == 'object').sum())
print((x_test3_le.dtypes == 'object').sum())
# Out:
# 0
# 0

# %%
x_train3_le.head()
# Out:
#       Diameter    Height    Length  Sex  Shell weight  Shucked weight  \
# 2848  0.395415  0.148420  0.485508    1      0.298993        0.464363
# 1773  0.281412  0.131028  0.381855    2      0.189794        0.308954
# 2054  0.307485  0.104360  0.381855    3      0.114221        0.236257
# 62    0.343590  0.122218  0.425268    1      0.182322        0.263902
# 1293  0.336472  0.122218  0.418710    2      0.165514        0.209450
#
#       Viscera weight  Whole weight
# 2848        0.230318      0.812706
# 1773        0.142801      0.566166
# 2054        0.081580      0.402461
# 62          0.176890      0.528567
# 1293        0.127953      0.459006

# %%
# LinearRegression
ols.fit(x_train3_le, y_train3)
ols_train4, ols_val4, ols_test4, ols_ser4 = print_score(ols,x_train3_le, y_train3, x_test3_le, y_test3)

# Ridge
rg.fit(x_train3_le, y_train3)
rg_train4, rg_val4, rg_test4, rg_ser4 = print_score(rg,x_train3_le, y_train3, x_test3_le, y_test3)


# RandomForestRegressor
rf.fit(x_train3_le, y_train3)
rf_train4, rf_val4, rf_test4, rf_ser4 = print_score(rf,x_train3_le, y_train3, x_test3_le, y_test3)

# SVR
svr.fit(x_train3_le, y_train3)
svr_train4, svr_val4, svr_test4, svr_ser4 = print_score(svr,x_train3_le, y_train3, x_test3_le, y_test3)

# XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_train3_le, y_train3)

xgb_train4, xgb_val4, xgb_test4, xgb_ser4 = print_score(xgb,x_train3_le, y_train3, x_test3_le, y_test3)

# %%
frame4 = {'ols':ols_ser4,'ridge':rg_ser4, 'rf':rf_ser4, 'svr':svr_ser4,'xgb':xgb_ser4}
pd.DataFrame(frame4)
# Out:
#          ols  ridge     rf    svr    xgb
# train  0.545  0.535  0.940  0.502  0.947
# val    0.540  0.529  0.550  0.489  0.503
# test   0.547  0.536  0.558  0.504  0.511

# %% [markdown]
# # **Part 3. Model Tuning**
# 비선형 회귀 모델 (RandomForestRegressor, XGBRegressor) <br>
# 💡 과대적합 발생원인 <br>
# - 데이터의 양이 충분하지 못할 경우
# - 분산이 크거나 노이즈가 심한 경우
# - 모델의 복잡도가 큰 경우 (모델의 학습 가능한 가중치의 개수)
# - 과도하게 큰 epoch로 학습하는 경우
# <br>
#
# 💡 모델 성능 향상 <br>
#
# ✅ **[Baseline]**<br>
# [Epoch 10, lr 0.001] <br>
# [Train Dataset] Loss = 5.863, Accuracy = 0.824 <br>
# [Test Dataset] Accuracy = 0.827 <br>

# %% [markdown]
# ## **3-1. GridSearchCV**

# %%
abalone4 = abalone.copy()

# 데이터 분리
target = 'Rings'
features4 = abalone4.columns.difference(['Rings','Sex'])
x_train4, x_test4, y_train4, y_test4 = data_split(abalone4, target, features4)
# Out:
# x_train: (3131, 7), y_train: (3131,)
# x_test: (1044, 7), y_test: (1044,)

# %%
# Log 변환
x_train4[numeric_feats] = np.log1p(x_train4[numeric_feats])
x_test4[numeric_feats] = np.log1p(x_test4[numeric_feats])

# %%
rf_grid = make_pipeline(
    RandomForestRegressor(
        n_estimators=200,
        max_depth=2,
        random_state = 42
    )
)
print(rf_grid)
# Out:
# Pipeline(steps=[('randomforestregressor',
#                  RandomForestRegressor(max_depth=2, n_estimators=200,
#                                        random_state=42))])

# %%
rf_params = {'randomforestregressor__n_estimators' : [100, 150, 200], 'randomforestregressor__max_depth': [4, 6, 8, 9, 10, 11, 12]}

# %%
rf_gridCV = GridSearchCV(rf_grid, param_grid=rf_params, scoring='r2', cv=5, verbose=3)
rf_gridCV.fit(x_train4, y_train4)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [CV 1/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=100;, score=0.476 total time=   0.5s
# [CV 2/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=100;, score=0.473 total time=   0.7s
# [CV 3/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=100;, score=0.495 total time=   0.7s
# [CV 4/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=100;, score=0.529 total time=   0.7s
# [CV 5/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=100;, score=0.461 total time=   0.8s
# [CV 1/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=150;, score=0.476 total time=   1.5s
# [CV 2/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=150;, score=0.476 total time=   1.1s
# [CV 3/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=150;, score=0.496 total time=   0.9s
# [CV 4/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=150;, score=0.531 total time=   0.9s
# [CV 5/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=150;, score=0.460 total time=   0.9s
# [CV 1/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=200;, score=0.476 total time=   1.2s
# [CV 2/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=200;, score=0.479 total time=   1.3s
# [CV 3/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=200;, score=0.497 total time=   1.4s
# [CV 4/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=200;, score=0.531 total time=   1.1s
# [CV 5/5] END randomforestregressor__max_depth=4, randomforestregressor__n_estimators=200;, score=0.461 total time=   1.2s
# [CV 1/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=100;, score=0.502 total time=   1.0s
# [CV 2/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=100;, score=0.507 total time=   3.3s
# [CV 3/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=100;, score=0.535 total time=   3.3s
# [CV 4/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=100;, score=0.579 total time=   2.1s
# [CV 5/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=100;, score=0.486 total time=   1.0s
# [CV 1/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=150;, score=0.501 total time=   1.6s
# [CV 2/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=150;, score=0.510 total time=   1.0s
# [CV 3/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=150;, score=0.535 total time=   0.9s
# [CV 4/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=150;, score=0.581 total time=   1.6s
# [CV 5/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=150;, score=0.487 total time=   3.3s
# [CV 1/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=200;, score=0.502 total time=   4.0s
# [CV 2/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=200;, score=0.511 total time=   2.2s
# [CV 3/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=200;, score=0.535 total time=   2.0s
# [CV 4/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=200;, score=0.580 total time=   1.2s
# [CV 5/5] END randomforestregressor__max_depth=6, randomforestregressor__n_estimators=200;, score=0.489 total time=   1.2s
# [CV 1/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=100;, score=0.503 total time=   0.8s
# [CV 2/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=100;, score=0.517 total time=   1.3s
# [CV 3/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=100;, score=0.543 total time=   2.5s
# [CV 4/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=100;, score=0.592 total time=   1.2s
# [CV 5/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=100;, score=0.492 total time=   1.6s
# [CV 1/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=150;, score=0.502 total time=   1.5s
# [CV 2/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=150;, score=0.516 total time=   1.2s
# [CV 3/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=150;, score=0.543 total time=   1.2s
# [CV 4/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=150;, score=0.595 total time=   1.2s
# [CV 5/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=150;, score=0.497 total time=   1.2s
# [CV 1/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=200;, score=0.505 total time=   1.6s
# [CV 2/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=200;, score=0.518 total time=   1.6s
# [CV 3/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=200;, score=0.542 total time=   2.4s
# [CV 4/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=200;, score=0.595 total time=   2.3s
# [CV 5/5] END randomforestregressor__max_depth=8, randomforestregressor__n_estimators=200;, score=0.497 total time=   1.5s
# [CV 1/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=100;, score=0.504 total time=   0.9s
# [CV 2/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=100;, score=0.519 total time=   0.9s
# [CV 3/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=100;, score=0.545 total time=   0.9s
# [CV 4/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=100;, score=0.597 total time=   0.9s
# [CV 5/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=100;, score=0.488 total time=   0.9s
# [CV 1/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=150;, score=0.502 total time=   1.3s
# [CV 2/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=150;, score=0.519 total time=   1.3s
# [CV 3/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=150;, score=0.546 total time=   1.4s
# [CV 4/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=150;, score=0.599 total time=   2.0s
# [CV 5/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=150;, score=0.493 total time=   2.5s
# [CV 1/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=200;, score=0.504 total time=   2.1s
# [CV 2/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=200;, score=0.519 total time=   1.7s
# [CV 3/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=200;, score=0.546 total time=   1.7s
# [CV 4/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=200;, score=0.599 total time=   1.7s
# [CV 5/5] END randomforestregressor__max_depth=9, randomforestregressor__n_estimators=200;, score=0.494 total time=   1.7s
# [CV 1/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=100;, score=0.502 total time=   0.9s
# [CV 2/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=100;, score=0.521 total time=   1.3s
# [CV 3/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=100;, score=0.541 total time=   1.4s
# [CV 4/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=100;, score=0.597 total time=   1.4s
# [CV 5/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=100;, score=0.489 total time=   1.1s
# [CV 1/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=150;, score=0.498 total time=   1.4s
# [CV 2/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=150;, score=0.518 total time=   1.4s
# [CV 3/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=150;, score=0.542 total time=   1.4s
# [CV 4/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=150;, score=0.599 total time=   1.4s
# [CV 5/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=150;, score=0.494 total time=   1.4s
# [CV 1/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=200;, score=0.501 total time=   1.8s
# [CV 2/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=200;, score=0.518 total time=   2.4s
# [CV 3/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=200;, score=0.541 total time=   2.7s
# [CV 4/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=200;, score=0.599 total time=   1.8s
# [CV 5/5] END randomforestregressor__max_depth=10, randomforestregressor__n_estimators=200;, score=0.495 total time=   1.8s
# [CV 1/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=100;, score=0.502 total time=   1.0s
# [CV 2/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=100;, score=0.515 total time=   1.0s
# [CV 3/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=100;, score=0.542 total time=   1.0s
# [CV 4/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=100;, score=0.597 total time=   1.0s
# [CV 5/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=100;, score=0.482 total time=   1.0s
# [CV 1/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=150;, score=0.498 total time=   1.6s
# [CV 2/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=150;, score=0.515 total time=   2.3s
# [CV 3/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=150;, score=0.542 total time=   2.1s
# [CV 4/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=150;, score=0.599 total time=   1.5s
# [CV 5/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=150;, score=0.490 total time=   1.5s
# [CV 1/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=200;, score=0.500 total time=   2.0s
# [CV 2/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=200;, score=0.516 total time=   2.0s
# [CV 3/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=200;, score=0.542 total time=   2.0s
# [CV 4/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=200;, score=0.599 total time=   2.6s
# [CV 5/5] END randomforestregressor__max_depth=11, randomforestregressor__n_estimators=200;, score=0.493 total time=   3.1s
# [CV 1/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=100;, score=0.499 total time=   1.4s
# [CV 2/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=100;, score=0.517 total time=   1.1s
# [CV 3/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=100;, score=0.543 total time=   1.1s
# [CV 4/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=100;, score=0.597 total time=   1.1s
# [CV 5/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=100;, score=0.481 total time=   1.0s
# [CV 1/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=150;, score=0.495 total time=   1.6s
# [CV 2/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=150;, score=0.517 total time=   1.6s
# [CV 3/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=150;, score=0.544 total time=   2.0s
# [CV 4/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=150;, score=0.599 total time=   2.3s
# [CV 5/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=150;, score=0.492 total time=   1.9s
# [CV 1/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=200;, score=0.499 total time=   2.1s
# [CV 2/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=200;, score=0.517 total time=   2.1s
# [CV 3/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=200;, score=0.543 total time=   2.1s
# [CV 4/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=200;, score=0.599 total time=   2.8s
# [CV 5/5] END randomforestregressor__max_depth=12, randomforestregressor__n_estimators=200;, score=0.491 total time=   3.4s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('randomforestregressor',
#                                         RandomForestRegressor(max_depth=2,
#                                                               n_estimators=200,
#                                                               random_state=42))]),
#              param_grid={'randomforestregressor__max_depth': [4, 6, 8, 9, 10,
#                                                               11, 12],
#                          'randomforestregressor__n_estimators': [100, 150,
#                                                                  200]},
#              scoring='r2', verbose=3)

# %%
print("최적 하이퍼파라미터: ", rf_gridCV.best_params_)
print("최적 AUC: ", rf_gridCV.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'randomforestregressor__max_depth': 9, 'randomforestregressor__n_estimators': 200}
# 최적 AUC:  0.5323714661998805

# %%
pd.DataFrame(rf_gridCV.cv_results_).sort_values(by="rank_test_score").T
# Out:
#                                                                                           11  \
# mean_fit_time                                                                       1.772477
# std_fit_time                                                                        0.159026
# mean_score_time                                                                     0.024618
# std_score_time                                                                      0.002718
# param_randomforestregressor__max_depth                                                     9
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 9, 'rando...
# split0_test_score                                                                   0.503827
# split1_test_score                                                                   0.519458
# split2_test_score                                                                   0.545769
# split3_test_score                                                                   0.598765
# split4_test_score                                                                   0.494039
# mean_test_score                                                                     0.532371
# std_test_score                                                                      0.037519
# rank_test_score                                                                            1
#
#                                                                                           10  \
# mean_fit_time                                                                       1.658683
# std_fit_time                                                                        0.418747
# mean_score_time                                                                     0.038109
# std_score_time                                                                       0.03276
# param_randomforestregressor__max_depth                                                     9
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 9, 'rando...
# split0_test_score                                                                   0.501659
# split1_test_score                                                                   0.519227
# split2_test_score                                                                   0.545998
# split3_test_score                                                                   0.598973
# split4_test_score                                                                   0.493196
# mean_test_score                                                                     0.531811
# std_test_score                                                                      0.038133
# rank_test_score                                                                            2
#
#                                                                                           8   \
# mean_fit_time                                                                       1.854504
# std_fit_time                                                                        0.370921
# mean_score_time                                                                     0.023637
# std_score_time                                                                      0.003551
# param_randomforestregressor__max_depth                                                     8
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 8, 'rando...
# split0_test_score                                                                   0.504933
# split1_test_score                                                                   0.518234
# split2_test_score                                                                   0.542334
# split3_test_score                                                                   0.594645
# split4_test_score                                                                   0.497436
# mean_test_score                                                                     0.531516
# std_test_score                                                                      0.035062
# rank_test_score                                                                            3
#
#                                                                                           14  \
# mean_fit_time                                                                       2.105215
# std_fit_time                                                                        0.371806
# mean_score_time                                                                     0.026258
# std_score_time                                                                      0.002452
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 10, 'rand...
# split0_test_score                                                                   0.501086
# split1_test_score                                                                   0.517636
# split2_test_score                                                                   0.541099
# split3_test_score                                                                   0.599367
# split4_test_score                                                                   0.495432
# mean_test_score                                                                     0.530924
# std_test_score                                                                      0.037721
# rank_test_score                                                                            4
#
#                                                                                           7   \
# mean_fit_time                                                                       1.216117
# std_fit_time                                                                        0.129794
# mean_score_time                                                                     0.017733
# std_score_time                                                                      0.004068
# param_randomforestregressor__max_depth                                                     8
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 8, 'rando...
# split0_test_score                                                                    0.50223
# split1_test_score                                                                   0.516366
# split2_test_score                                                                   0.543438
# split3_test_score                                                                   0.594705
# split4_test_score                                                                   0.497197
# mean_test_score                                                                     0.530787
# std_test_score                                                                       0.03577
# rank_test_score                                                                            5
#
#                                                                                           9   \
# mean_fit_time                                                                       0.859069
# std_fit_time                                                                        0.007547
# mean_score_time                                                                     0.013081
# std_score_time                                                                      0.000783
# param_randomforestregressor__max_depth                                                     9
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 9, 'rando...
# split0_test_score                                                                   0.503754
# split1_test_score                                                                   0.518964
# split2_test_score                                                                   0.545264
# split3_test_score                                                                   0.597236
# split4_test_score                                                                    0.48789
# mean_test_score                                                                     0.530621
# std_test_score                                                                      0.038303
# rank_test_score                                                                            6
#
#                                                                                           13  \
# mean_fit_time                                                                       1.353473
# std_fit_time                                                                         0.01831
# mean_score_time                                                                      0.01916
# std_score_time                                                                      0.000155
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 10, 'rand...
# split0_test_score                                                                   0.498078
# split1_test_score                                                                   0.517995
# split2_test_score                                                                   0.542413
# split3_test_score                                                                   0.599075
# split4_test_score                                                                   0.494372
# mean_test_score                                                                     0.530386
# std_test_score                                                                      0.038359
# rank_test_score                                                                            7
#
#                                                                                           17  \
# mean_fit_time                                                                        2.27442
# std_fit_time                                                                        0.395051
# mean_score_time                                                                     0.047736
# std_score_time                                                                      0.037188
# param_randomforestregressor__max_depth                                                    11
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 11, 'rand...
# split0_test_score                                                                   0.500195
# split1_test_score                                                                   0.516487
# split2_test_score                                                                   0.541791
# split3_test_score                                                                   0.599145
# split4_test_score                                                                   0.492754
# mean_test_score                                                                     0.530074
# std_test_score                                                                      0.038414
# rank_test_score                                                                            8
#
#                                                                                           12  \
# mean_fit_time                                                                       1.194477
# std_fit_time                                                                        0.178535
# mean_score_time                                                                     0.017094
# std_score_time                                                                      0.001733
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 10, 'rand...
# split0_test_score                                                                   0.502286
# split1_test_score                                                                   0.520543
# split2_test_score                                                                   0.541169
# split3_test_score                                                                    0.59726
# split4_test_score                                                                   0.488742
# mean_test_score                                                                         0.53
# std_test_score                                                                      0.037969
# rank_test_score                                                                            9
#
#                                                                                           20  \
# mean_fit_time                                                                       2.478599
# std_fit_time                                                                        0.514289
# mean_score_time                                                                     0.033911
# std_score_time                                                                      0.008052
# param_randomforestregressor__max_depth                                                    12
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 12, 'rand...
# split0_test_score                                                                   0.498929
# split1_test_score                                                                   0.516931
# split2_test_score                                                                   0.543165
# split3_test_score                                                                   0.598985
# split4_test_score                                                                   0.491382
# mean_test_score                                                                     0.529878
# std_test_score                                                                      0.038884
# rank_test_score                                                                           10
#
#                                            ...  \
# mean_fit_time                              ...
# std_fit_time                               ...
# mean_score_time                            ...
# std_score_time                             ...
# param_randomforestregressor__max_depth     ...
# param_randomforestregressor__n_estimators  ...
# params                                     ...
# split0_test_score                          ...
# split1_test_score                          ...
# split2_test_score                          ...
# split3_test_score                          ...
# split4_test_score                          ...
# mean_test_score                            ...
# std_test_score                             ...
# rank_test_score                            ...
#
#                                                                                           19  \
# mean_fit_time                                                                       1.855846
# std_fit_time                                                                        0.266437
# mean_score_time                                                                     0.023645
# std_score_time                                                                      0.003467
# param_randomforestregressor__max_depth                                                    12
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 12, 'rand...
# split0_test_score                                                                   0.495426
# split1_test_score                                                                   0.516912
# split2_test_score                                                                   0.544028
# split3_test_score                                                                   0.598711
# split4_test_score                                                                   0.491744
# mean_test_score                                                                     0.529364
# std_test_score                                                                       0.03936
# rank_test_score                                                                           12
#
#                                                                                           16  \
# mean_fit_time                                                                       1.767274
# std_fit_time                                                                        0.333239
# mean_score_time                                                                     0.024275
# std_score_time                                                                      0.003911
# param_randomforestregressor__max_depth                                                    11
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 11, 'rand...
# split0_test_score                                                                   0.498455
# split1_test_score                                                                   0.515104
# split2_test_score                                                                   0.542293
# split3_test_score                                                                   0.599372
# split4_test_score                                                                   0.490114
# mean_test_score                                                                     0.529068
# std_test_score                                                                      0.039414
# rank_test_score                                                                           13
#
#                                                                                           15  \
# mean_fit_time                                                                       0.988791
# std_fit_time                                                                        0.020911
# mean_score_time                                                                     0.015792
# std_score_time                                                                      0.002331
# param_randomforestregressor__max_depth                                                    11
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 11, 'rand...
# split0_test_score                                                                   0.502124
# split1_test_score                                                                   0.515076
# split2_test_score                                                                   0.541841
# split3_test_score                                                                    0.59732
# split4_test_score                                                                   0.482485
# mean_test_score                                                                     0.527769
# std_test_score                                                                      0.039761
# rank_test_score                                                                           14
#
#                                                                                           18  \
# mean_fit_time                                                                       1.104476
# std_fit_time                                                                        0.120326
# mean_score_time                                                                     0.014441
# std_score_time                                                                      0.000317
# param_randomforestregressor__max_depth                                                    12
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 12, 'rand...
# split0_test_score                                                                   0.499392
# split1_test_score                                                                   0.516747
# split2_test_score                                                                   0.542933
# split3_test_score                                                                    0.59722
# split4_test_score                                                                   0.481244
# mean_test_score                                                                     0.527507
# std_test_score                                                                      0.040359
# rank_test_score                                                                           15
#
#                                                                                           5   \
# mean_fit_time                                                                       2.097273
# std_fit_time                                                                        0.998673
# mean_score_time                                                                     0.025906
# std_score_time                                                                      0.009403
# param_randomforestregressor__max_depth                                                     6
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 6, 'rando...
# split0_test_score                                                                   0.501961
# split1_test_score                                                                   0.511494
# split2_test_score                                                                   0.534704
# split3_test_score                                                                   0.579641
# split4_test_score                                                                   0.488873
# mean_test_score                                                                     0.523334
# std_test_score                                                                      0.031888
# rank_test_score                                                                           16
#
#                                                                                           4   \
# mean_fit_time                                                                       1.652839
# std_fit_time                                                                        0.849754
# mean_score_time                                                                     0.022352
# std_score_time                                                                      0.011631
# param_randomforestregressor__max_depth                                                     6
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 6, 'rando...
# split0_test_score                                                                   0.500941
# split1_test_score                                                                   0.509771
# split2_test_score                                                                   0.535001
# split3_test_score                                                                   0.580584
# split4_test_score                                                                   0.487162
# mean_test_score                                                                     0.522692
# std_test_score                                                                       0.03288
# rank_test_score                                                                           17
#
#                                                                                           3   \
# mean_fit_time                                                                       2.129223
# std_fit_time                                                                         1.02114
# mean_score_time                                                                     0.026858
# std_score_time                                                                      0.010739
# param_randomforestregressor__max_depth                                                     6
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 6, 'rando...
# split0_test_score                                                                   0.502273
# split1_test_score                                                                    0.50739
# split2_test_score                                                                   0.535406
# split3_test_score                                                                   0.578856
# split4_test_score                                                                   0.485658
# mean_test_score                                                                     0.521917
# std_test_score                                                                      0.032667
# rank_test_score                                                                           18
#
#                                                                                           2   \
# mean_fit_time                                                                        1.24624
# std_fit_time                                                                        0.095623
# mean_score_time                                                                     0.022541
# std_score_time                                                                      0.006599
# param_randomforestregressor__max_depth                                                     4
# param_randomforestregressor__n_estimators                                                200
# params                                     {'randomforestregressor__max_depth': 4, 'rando...
# split0_test_score                                                                    0.47632
# split1_test_score                                                                   0.478511
# split2_test_score                                                                    0.49701
# split3_test_score                                                                   0.531361
# split4_test_score                                                                   0.460973
# mean_test_score                                                                     0.488835
# std_test_score                                                                      0.024145
# rank_test_score                                                                           19
#
#                                                                                           1   \
# mean_fit_time                                                                       1.039717
# std_fit_time                                                                        0.240667
# mean_score_time                                                                     0.017179
# std_score_time                                                                      0.004388
# param_randomforestregressor__max_depth                                                     4
# param_randomforestregressor__n_estimators                                                150
# params                                     {'randomforestregressor__max_depth': 4, 'rando...
# split0_test_score                                                                   0.476139
# split1_test_score                                                                   0.475863
# split2_test_score                                                                    0.49564
# split3_test_score                                                                   0.530864
# split4_test_score                                                                   0.460133
# mean_test_score                                                                     0.487728
# std_test_score                                                                      0.024331
# rank_test_score                                                                           20
#
#                                                                                           0
# mean_fit_time                                                                       0.648036
# std_fit_time                                                                         0.09924
# mean_score_time                                                                     0.015521
# std_score_time                                                                      0.008501
# param_randomforestregressor__max_depth                                                     4
# param_randomforestregressor__n_estimators                                                100
# params                                     {'randomforestregressor__max_depth': 4, 'rando...
# split0_test_score                                                                   0.476145
# split1_test_score                                                                   0.473095
# split2_test_score                                                                   0.494724
# split3_test_score                                                                   0.529482
# split4_test_score                                                                    0.46122
# mean_test_score                                                                     0.486933
# std_test_score                                                                      0.023833
# rank_test_score                                                                           21
#
# [15 rows x 21 columns]

# %%
xgb_grid = XGBRegressor(n_estimators=10000,
                        max_depth=5,
                        learning_rate=0.01,
                        n_jobs=5,
                        early_stopping_rounds=30,
                        random_state=42)
print(xgb_grid)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=5, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
xgb_params={ 'max_depth':[2, 4, 6, 8,9, 10],'learning_rate':[0.03, 0.05, 0.07]}

# %%
xgb_gridCV = GridSearchCV(xgb_grid, xgb_params, scoring='r2', cv=5, verbose=3)
xgb_gridCV.fit(x_train4, y_train4)
# Must have at least 1 validation dataset for early stopping.

# %%
print("최적 하이퍼파라미터: ", xgb_gridCV.best_params_)
print("최적 AUC: ", xgb_gridCV.best_score_)

# %% [markdown]
# ## **3-2. Randomized SearchCV**

# %%
rr_params = {
    'n_estimators' : [100, 150, 200],
    'max_depth': [4, 6, 8, 9, 10, 11, 12]
}

# %%
rf_rs = RandomForestRegressor(max_depth=2,
                              random_state=42,
                              n_jobs=1)

# %%
rsCV = RandomizedSearchCV(
    rf_rs,
    rr_params,
    scoring='r2',
    n_iter=10,
    cv=5,
    verbose=3,
    random_state=42
)

rsCV.fit(x_train4, y_train4)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END .....max_depth=4, n_estimators=100;, score=0.476 total time=   1.5s
# [CV 2/5] END .....max_depth=4, n_estimators=100;, score=0.473 total time=   0.7s
# [CV 3/5] END .....max_depth=4, n_estimators=100;, score=0.495 total time=   0.7s
# [CV 4/5] END .....max_depth=4, n_estimators=100;, score=0.529 total time=   0.5s
# [CV 5/5] END .....max_depth=4, n_estimators=100;, score=0.461 total time=   0.5s
# [CV 1/5] END ....max_depth=11, n_estimators=200;, score=0.500 total time=   2.0s
# [CV 2/5] END ....max_depth=11, n_estimators=200;, score=0.516 total time=   2.0s
# [CV 3/5] END ....max_depth=11, n_estimators=200;, score=0.542 total time=   1.9s
# [CV 4/5] END ....max_depth=11, n_estimators=200;, score=0.599 total time=   2.1s
# [CV 5/5] END ....max_depth=11, n_estimators=200;, score=0.493 total time=   2.9s
# [CV 1/5] END ....max_depth=11, n_estimators=100;, score=0.502 total time=   1.4s
# [CV 2/5] END ....max_depth=11, n_estimators=100;, score=0.515 total time=   1.0s
# [CV 3/5] END ....max_depth=11, n_estimators=100;, score=0.542 total time=   1.0s
# [CV 4/5] END ....max_depth=11, n_estimators=100;, score=0.597 total time=   1.0s
# [CV 5/5] END ....max_depth=11, n_estimators=100;, score=0.482 total time=   1.1s
# [CV 1/5] END .....max_depth=4, n_estimators=150;, score=0.476 total time=   0.7s
# [CV 2/5] END .....max_depth=4, n_estimators=150;, score=0.476 total time=   0.7s
# [CV 3/5] END .....max_depth=4, n_estimators=150;, score=0.496 total time=   0.7s
# [CV 4/5] END .....max_depth=4, n_estimators=150;, score=0.531 total time=   0.7s
# [CV 5/5] END .....max_depth=4, n_estimators=150;, score=0.460 total time=   0.7s
# [CV 1/5] END .....max_depth=8, n_estimators=200;, score=0.505 total time=   1.6s
# [CV 2/5] END .....max_depth=8, n_estimators=200;, score=0.518 total time=   2.0s
# [CV 3/5] END .....max_depth=8, n_estimators=200;, score=0.542 total time=   2.3s
# [CV 4/5] END .....max_depth=8, n_estimators=200;, score=0.595 total time=   1.8s
# [CV 5/5] END .....max_depth=8, n_estimators=200;, score=0.497 total time=   1.5s
# [CV 1/5] END .....max_depth=6, n_estimators=200;, score=0.502 total time=   1.3s
# [CV 2/5] END .....max_depth=6, n_estimators=200;, score=0.511 total time=   1.3s
# [CV 3/5] END .....max_depth=6, n_estimators=200;, score=0.535 total time=   1.3s
# [CV 4/5] END .....max_depth=6, n_estimators=200;, score=0.580 total time=   1.5s
# [CV 5/5] END .....max_depth=6, n_estimators=200;, score=0.489 total time=   1.9s
# [CV 1/5] END .....max_depth=9, n_estimators=200;, score=0.504 total time=   2.7s
# [CV 2/5] END .....max_depth=9, n_estimators=200;, score=0.519 total time=   2.7s
# [CV 3/5] END .....max_depth=9, n_estimators=200;, score=0.546 total time=   2.0s
# [CV 4/5] END .....max_depth=9, n_estimators=200;, score=0.599 total time=   1.7s
# [CV 5/5] END .....max_depth=9, n_estimators=200;, score=0.494 total time=   1.7s
# [CV 1/5] END .....max_depth=6, n_estimators=100;, score=0.502 total time=   0.6s
# [CV 2/5] END .....max_depth=6, n_estimators=100;, score=0.507 total time=   0.6s
# [CV 3/5] END .....max_depth=6, n_estimators=100;, score=0.535 total time=   0.6s
# [CV 4/5] END .....max_depth=6, n_estimators=100;, score=0.579 total time=   0.6s
# [CV 5/5] END .....max_depth=6, n_estimators=100;, score=0.486 total time=   0.6s
# [CV 1/5] END ....max_depth=12, n_estimators=100;, score=0.499 total time=   1.0s
# [CV 2/5] END ....max_depth=12, n_estimators=100;, score=0.517 total time=   1.1s
# [CV 3/5] END ....max_depth=12, n_estimators=100;, score=0.543 total time=   1.5s
# [CV 4/5] END ....max_depth=12, n_estimators=100;, score=0.597 total time=   1.6s
# [CV 5/5] END ....max_depth=12, n_estimators=100;, score=0.481 total time=   1.5s
# [CV 1/5] END ....max_depth=11, n_estimators=150;, score=0.498 total time=   1.5s
# [CV 2/5] END ....max_depth=11, n_estimators=150;, score=0.515 total time=   1.5s
# [CV 3/5] END ....max_depth=11, n_estimators=150;, score=0.542 total time=   1.5s
# [CV 4/5] END ....max_depth=11, n_estimators=150;, score=0.599 total time=   1.5s
# [CV 5/5] END ....max_depth=11, n_estimators=150;, score=0.490 total time=   1.5s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestRegressor(max_depth=2, n_jobs=1,
#                                                    random_state=42),
#                    param_distributions={'max_depth': [4, 6, 8, 9, 10, 11, 12],
#                                         'n_estimators': [100, 150, 200]},
#                    random_state=42, scoring='r2', verbose=3)

# %%
print("최적 하이퍼파라미터: ", rsCV.best_params_)
print("최적 AUC: ", rsCV.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'n_estimators': 200, 'max_depth': 9}
# 최적 AUC:  0.5323714661998805
